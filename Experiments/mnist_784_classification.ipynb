# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt

X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X.astype('int')
y = y.astype('int')
X3 = X[y <= 3]
y3 = y[y <= 3]

mlp = MLPClassifier(hidden_layer_sizes=(25, ), solver='adam', alpha=1e-2, random_state=2,max_iter=2500)
mlp.fit(X3, y3)

fig, axes = plt.subplots(5, 5, figsize=(20, 15))
for i, ax in enumerate(axes.ravel()):
    coef = mlp.coefs_[0][:, i]
    ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray)
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(i+1)
plt.show()

# %%
print(f"Accuracy (cross validated): {cv_results['test_score']}")
# Out:
# Accuracy (cross validated): [nan nan nan nan nan]

# %%
fig, axes = plt.subplots(5, 5, figsize=(20, 15))
for i, ax in enumerate(axes.ravel()):
    coef = mlp.coefs_[0][:, i]
    ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray)
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(i+1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-87d9ea10fe29> in <module>
#       1 fig, axes = plt.subplots(5, 5, figsize=(20, 15))
#       2 for i, ax in enumerate(axes.ravel()):
# ----> 3     coef = mlp.coefs_[0][:, i]
#       4     ax.matshow(coef.reshape(28, 28), cmap=plt.cm.gray)
#       5     ax.set_xticks(())
#
# AttributeError: 'MLPClassifier' object has no attribute 'coefs_'
