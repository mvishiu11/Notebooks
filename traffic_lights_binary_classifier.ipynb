# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
folder = os.path.join('/content/traffic_light_data/train')
onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

print("Working with {0} images".format(len(onlyfiles)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-98c3d89c1dab> in <module>
#       1 folder = os.path.join('/content/traffic_light_data/train')
# ----> 2 onlyfiles = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]
#       3
#       4 print("Working with {0} images".format(len(onlyfiles)))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/traffic_light_data/train'

# %%
train_files = []
y_train = []
i=0
for _file in onlyfiles:
    train_files.append(_file)
    label_in_file = _file.find("_")
    y_train.append(int(_file[0:label_in_file]))
    
print("Files in train_files: %d" % len(train_files))

# Original Dimensions
image_width = 640
image_height = 480
ratio = 4

image_width = int(image_width / ratio)
image_height = int(image_height / ratio)

channels = 3
nb_classes = 1

dataset = np.ndarray(shape=(len(train_files), channels, image_height, image_width),
                     dtype=np.float32)

i = 0
for _file in train_files:
    img = load_img(folder + "/" + _file)  # this is a PIL image
    img.thumbnail((image_width, image_height))
    # Convert to Numpy Array
    x = img_to_array(img)  
    x = x.reshape((3, 120, 160))
    # Normalize
    x = (x - 128.0) / 128.0
    dataset[i] = x
    i += 1
    if i % 250 == 0:
        print("%d images to array" % i)
print("All images to array!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-b50677863727> in <module>
#       5     train_files.append(_file)
#       6     label_in_file = _file.find("_")
# ----> 7     y_train.append(int(_file[0:label_in_file]))
#       8
#       9 print("Files in train_files: %d" % len(train_files))
#
# ValueError: invalid literal for int() with base 10: 'yellow'
