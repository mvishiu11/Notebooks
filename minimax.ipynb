# %%
X = "X"
O = "O"
EMPTY = None

board = [[X, O, EMPTY],
         [EMPTY, X, O],
         [EMPTY, EMPTY, EMPTY]]

# %%
sum([i.count(X) for i in board])
# Out:
# 2

# %%
def player(board):
    """
    Returns player who has the next turn on a board.
    """
    if sum([i.count(X) for i in board]) > sum([i.count(O) for i in board]):
      return O
    else:
      return X

# %%
player(board)
# Out:
# 'X'

# %%
board[0][0]
# Out:
# 'X'

# %%
def actions(board):
    """
    Returns set of all possible actions (i, j) available on the board.
    """
    actions = []
    i = 0 
    j = 0
    for row in board:
      for column in row:
        if board[i][j] == EMPTY:
          actions.append((i, j))
        j += 1
      j = 0  
      i += 1
    return actions

# %%
(actions(board)[2])[1]
# Out:
# 0

# %%
import copy
def result(board, action):
    """
    Returns the board that results from making move (i, j) on the board.
    """
    new_board = copy.deepcopy(board)
    if player(board) == X:
      new_board[action[0]][action[1]] = X
    else:
      new_board[action[0]][action[1]] = O
    return new_board

# %%
result(board, (0, 1))
# Out:
# [['X', 'X', None], [None, 'X', 'O'], [None, None, None]]

# %%
board
# Out:
# [['X', 'O', None], [None, 'X', 'O'], [None, None, None]]

# %%
id(board)
# Out:
# 140071617889472

# %%
def winner(board):
    """
    Returns the winner of the game, if there is one.
    """
    if (board[0][0] == board[1][1] == board[2][2]):
      return board[0][0]
    if (board[0][2] == board[1][1] == board[2][0]):
      return board[0][2]
    for i in range(3):
      if (board[i][0] == board[i][1] == board[i][2]):
        return board[i][0]
      elif (board[0][i] == board[1][i] == board[2][i]):
        return board[0][i]
    return EMPTY

# %%
winner(board)
# Out:
# 'O'

# %%
def terminal(board):
    """
    Returns True if game is over, False otherwise.
    """
    if winner(board) != EMPTY:
      return True
    elif sum([i.count(EMPTY) for i in board]) == 0:
      return True
    return False

# %%
terminal(board)
# Out:
# False

# %%
def utility(board):
    """
    Returns 1 if X has won the game, -1 if O has won, 0 otherwise.
    """
    if winner(board) == X:
      return 1
    elif winner(board) == O:
      return -1
    else:
      return 0

# %%
utility(board)
# Out:
# 0

# %%
def minimax(board):
    """
    Returns the optimal action for the current player on the board.
    """
    def max_value(board):
      v = -2
      if terminal(board):
        return utility(board)
      for action in actions(board):
        v = max(v, min_value(result(board, action)))
      return v

    def min_value(board):
      v = 2
      if terminal(board):
        return utility(board)
      for action in actions(board):
       v = min(v, max_value(result(board, action)))
      return v

    optimal_action = ()
    v = 0
    v_p = 0
    if terminal(board):
      print("None")
      return None
    if player(board) == X:
      for action in actions(board):
        v_p = v
        v = max_value(result(board, action))
        print(v, v_p)
        if v_p >= v:
          optimal_action = action
      return optimal_action
    else:
      for action in actions(board):
        v_p = v
        v = min_value(result(board, action))
        if v_p <= v:
          optimal_action = action
      return optimal_action

# %%
board = [[EMPTY, O, O],
         [X, O, X],
         [O, X, X]]

# %%
minimax(board)
# Out:
# None

# %%
terminal(board)
# Out:
# True

# %%
board = result(board, (1, 0))

# %%
board
# Out:
# [[None, None, None], ['X', 'O', 'X'], [None, 'O', 'X']]

# %%
board
# Out:
# [['X', 'O', None], [None, 'X', 'O'], [None, None, None]]

# %%
import copy
arr = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
arr_2 = copy.deepcopy(arr)
print(arr, id(arr), arr_2, id(arr_2))

arr_2[0][0] = 0
print(arr, id(arr), arr_2, id(arr_2))
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]] 140071617593856 [[1, 2, 3], [4, 5, 6], [7, 8, 9]] 140071617611584
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]] 140071617593856 [[0, 2, 3], [4, 5, 6], [7, 8, 9]] 140071617611584

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2
